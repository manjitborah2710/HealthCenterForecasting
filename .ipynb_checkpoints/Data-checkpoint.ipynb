# %%
import pandas as pd
import numpy as np
from pandas import datetime
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def parser(x):
    return datetime.strptime(x,'%m/%d/%Y')

# %%
data = pd.read_csv("jun-oct 18.csv", index_col=0, parse_dates=[0], date_parser=parser)
data = data.dropna()
data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\program files\python36\lib\site-packages\pandas\io\parsers.py in converter(*date_cols)
#    3269                 result = tools.to_datetime(
# -> 3270                     date_parser(*date_cols), errors="ignore", cache=cache_dates
#    3271                 )
#
# <ipython-input-2-9d9342f02539> in parser(x)
#       1 def parser(x):
# ----> 2     return datetime.strptime(x,'%m/%d/%Y')
#
# TypeError: strptime() argument 1 must be str, not numpy.ndarray
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# c:\program files\python36\lib\site-packages\pandas\io\parsers.py in converter(*date_cols)
#    3280                             parser=date_parser,
# -> 3281                             dayfirst=dayfirst,
#    3282                         ),
#
# pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.try_parse_dates()
#
# pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.try_parse_dates()
#
# <ipython-input-2-9d9342f02539> in parser(x)
#       1 def parser(x):
# ----> 2     return datetime.strptime(x,'%m/%d/%Y')
#
# c:\program files\python36\lib\_strptime.py in _strptime_datetime(cls, data_string, format)
#     564     format string."""
# --> 565     tt, fraction = _strptime(data_string, format)
#     566     tzname, gmtoff = tt[-2:]
#
# c:\program files\python36\lib\_strptime.py in _strptime(data_string, format)
#     361         raise ValueError("time data %r does not match format %r" %
# --> 362                          (data_string, format))
#     363     if len(data_string) != found.end():
#
# ValueError: time data '2-7-2018' does not match format '%m/%d/%Y'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-fafa2a1f90e5> in <module>
# ----> 1 data = pd.read_csv("jun-oct 18.csv", index_col=0, parse_dates=[0], date_parser=parser)
#       2 data = data.dropna()
#       3 data
#
# c:\program files\python36\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# c:\program files\python36\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     461
#     462     try:
# --> 463         data = parser.read(nrows)
#     464     finally:
#     465         parser.close()
#
# c:\program files\python36\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1152     def read(self, nrows=None):
#    1153         nrows = _validate_integer("nrows", nrows)
# -> 1154         ret = self._engine.read(nrows)
#    1155
#    1156         # May alter columns / col_dict
#
# c:\program files\python36\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    2122
#    2123             names, data = self._do_date_conversions(names, data)
# -> 2124             index, names = self._make_index(data, alldata, names)
#    2125
#    2126         # maybe create a mi on the columns
#
# c:\program files\python36\lib\site-packages\pandas\io\parsers.py in _make_index(self, data, alldata, columns, indexnamerow)
#    1567         elif not self._has_complex_date_col:
#    1568             index = self._get_simple_index(alldata, columns)
# -> 1569             index = self._agg_index(index)
#    1570         elif self._has_complex_date_col:
#    1571             if not self._name_processed:
#
# c:\program files\python36\lib\site-packages\pandas\io\parsers.py in _agg_index(self, index, try_parse_dates)
#    1648
#    1649             if try_parse_dates and self._should_parse_dates(i):
# -> 1650                 arr = self._date_conv(arr)
#    1651
#    1652             if self.na_filter:
#
# c:\program files\python36\lib\site-packages\pandas\io\parsers.py in converter(*date_cols)
#    3284                     )
#    3285                 except Exception:
# -> 3286                     return generic_parser(date_parser, *date_cols)
#    3287
#    3288     return converter
#
# c:\program files\python36\lib\site-packages\pandas\io\date_converters.py in generic_parser(parse_func, *cols)
#      36     for i in range(N):
#      37         args = [c[i] for c in cols]
# ---> 38         results[i] = parse_func(*args)
#      39
#      40     return results
#
# <ipython-input-2-9d9342f02539> in parser(x)
#       1 def parser(x):
# ----> 2     return datetime.strptime(x,'%m/%d/%Y')
#
# c:\program files\python36\lib\_strptime.py in _strptime_datetime(cls, data_string, format)
#     563     """Return a class cls instance based on the input string and the
#     564     format string."""
# --> 565     tt, fraction = _strptime(data_string, format)
#     566     tzname, gmtoff = tt[-2:]
#     567     args = tt[:6] + (fraction,)
#
# c:\program files\python36\lib\_strptime.py in _strptime(data_string, format)
#     360     if not found:
#     361         raise ValueError("time data %r does not match format %r" %
# --> 362                          (data_string, format))
#     363     if len(data_string) != found.end():
#     364         raise ValueError("unconverted data remains: %s" %
#
# ValueError: time data '2-7-2018' does not match format '%m/%d/%Y'

# %%
total_freq = data.sum()
total_freq
# Out:
# Acidity                         81
# Urti                           209
# Indigestion                     72
# Hypertension                     4
# Dehydration                      1
# Low BP                           1
# Oral ulcer                      22
# Anaemia                          1
# old abbrassion                   2
# Fungal infection                62
# Abdomen pain                     3
# Itching                         28
# Cough                           12
# Cold                            92
# Ear Infection                    3
# GAD                              1
# APD                              5
# Throat pain                      5
# Back pain                        7
# General weakness                 6
# Gastritis                        1
# Epigastric pain                  3
# Fever                           55
# Whooping cough                   0
# Breathlessness                   1
# Hairfall                         1
# Headache                        15
# Giddiness                        6
# Worm infection                   2
# Rheumatic fever                  1
# Vomitting                        5
# Myalgia                          6
# Running nose                     9
# pharyngotis                      3
# Vitamin Deficiency               0
# vertigo                          4
# allergy                          4
# Loss of appetite                 5
# injury/cut                      23
# Asthama                          1
# Ring worm                        8
# foot pain                        3
# pain wrist                       1
# Swelling                         6
# watering of eye                  1
# weakness                         0
# Knee pain                        2
# LRTI                             5
# Diarhoea                         6
# Dysentry                         2
# Systeric HTN                     2
# acute torillitis                 1
# follicular torillitis            1
# Burn                             2
# Lathergy                         3
# Blood Clot                       1
# dtype: int64

# %%
total_freq.max()
# Out:
# 209

# %%
data_month_freq = data.groupby([lambda x: x.year, lambda x: x.month]).sum()
data_month_freq
# Out:
#          Acidity  Urti  Indigestion  Hypertension  Dehydration  Low BP  \
# 2018 6         3     3            1             2            1       1
#      7        19    32           18             0            0       0
#      8        30    78           25             0            0       0
#      9        15    46           14             2            0       0
#      10       14    50           14             0            0       0
#
#          Oral ulcer  Anaemia  old abbrassion  Fungal infection  ...  \
# 2018 6            1        1               0                 1  ...
#      7            4        0               2                 8  ...
#      8           11        0               0                13  ...
#      9            3        0               0                34  ...
#      10           3        0               0                 6  ...
#
#          Knee pain  LRTI  Diarhoea  Dysentry  Systeric HTN  acute torillitis  \
# 2018 6           0     0         0         0             0                 0
#      7           0     0         0         0             0                 0
#      8           2     0         0         0             0                 0
#      9           0     5         5         1             2                 1
#      10          0     0         1         1             0                 0
#
#          follicular torillitis        Burn  Lathergy  Blood Clot
# 2018 6                             0     0         0           0
#      7                             0     0         0           0
#      8                             0     0         0           0
#      9                             1     2         3           1
#      10                            0     0         0           0
#
# [5 rows x 56 columns]

# %%
total_freq.sort_values(ascending=False)
# Out:
# Urti                           209
# Cold                            92
# Acidity                         81
# Indigestion                     72
# Fungal infection                62
# Fever                           55
# Itching                         28
# injury/cut                      23
# Oral ulcer                      22
# Headache                        15
# Cough                           12
# Running nose                     9
# Ring worm                        8
# Back pain                        7
# General weakness                 6
# Myalgia                          6
# Giddiness                        6
# Diarhoea                         6
# Swelling                         6
# Throat pain                      5
# LRTI                             5
# Loss of appetite                 5
# Vomitting                        5
# APD                              5
# allergy                          4
# vertigo                          4
# Hypertension                     4
# Epigastric pain                  3
# Ear Infection                    3
# Abdomen pain                     3
# Lathergy                         3
# foot pain                        3
# pharyngotis                      3
# Worm infection                   2
# Systeric HTN                     2
# old abbrassion                   2
# Burn                             2
# Knee pain                        2
# Dysentry                         2
# Asthama                          1
# Anaemia                          1
# acute torillitis                 1
# Dehydration                      1
# follicular torillitis            1
# Low BP                           1
# Blood Clot                       1
# GAD                              1
# Gastritis                        1
# watering of eye                  1
# Breathlessness                   1
# Hairfall                         1
# Rheumatic fever                  1
# pain wrist                       1
# Whooping cough                   0
# Vitamin Deficiency               0
# weakness                         0
# dtype: int64

# %%
data = data.drop(columns=['Whooping cough', 'Vitamin Deficiency', 'weakness'])
corrltn = data.corr()
corrltn
# Out:
#                               Acidity      Urti  Indigestion  Hypertension  \
# Acidity                      1.000000  0.379496     0.809993      0.016690
# Urti                         0.379496  1.000000     0.362481     -0.014220
# Indigestion                  0.809993  0.362481     1.000000     -0.017291
# Hypertension                 0.016690 -0.014220    -0.017291      1.000000
# Dehydration                  0.127075 -0.064315     0.018875      0.491202
# Low BP                       0.127075 -0.064315     0.018875      0.491202
# Oral ulcer                  -0.011542  0.139746     0.039480     -0.104745
# Anaemia                     -0.110678 -0.110180    -0.090598     -0.023672
# old abbrassion               0.011662 -0.156731     0.104712     -0.033674
# Fungal infection            -0.020818  0.195924     0.063264      0.217000
# Abdomen pain                 0.083814 -0.112716     0.097030     -0.041487
# Itching                      0.158472  0.059634     0.070430     -0.024868
# Cough                       -0.043083 -0.153509    -0.031506      0.071347
# Cold                        -0.025395  0.055308     0.042823     -0.092371
# Ear Infection               -0.055078 -0.032337    -0.094825      0.259294
# GAD                          0.008198 -0.064315    -0.090598      0.491202
# APD                          0.152585 -0.035403     0.162243      0.152160
# Throat pain                  0.106967 -0.141004     0.162243     -0.045421
# Back pain                   -0.102429 -0.028511    -0.104663     -0.056721
# General weakness            -0.129327 -0.181623    -0.044463     -0.059748
# Gastritis                   -0.110678 -0.064315    -0.090598     -0.023672
# Epigastric pain             -0.193969 -0.166302    -0.158777     -0.041487
# Fever                        0.164751  0.148429     0.254771      0.026286
# Breathlessness              -0.110678 -0.110180    -0.090598     -0.023672
# Hairfall                    -0.110678 -0.110180    -0.090598     -0.023672
# Headache                     0.166209 -0.010993     0.268511      0.156316
# Giddiness                   -0.079321 -0.143036    -0.044463     -0.059748
# Worm infection              -0.157440 -0.124110    -0.128876     -0.033674
# Rheumatic fever             -0.110678 -0.110180    -0.090598     -0.023672
# Vomitting                   -0.075506  0.017398    -0.047804     -0.045421
# Myalgia                      0.020692 -0.181623     0.047638     -0.059748
# Running nose                -0.011952 -0.129118     0.016010     -0.056473
# pharyngotis                  0.011051 -0.004264     0.123815     -0.031909
# vertigo                      0.137696 -0.130935     0.205575     -0.048193
# allergy                     -0.043812 -0.130935     0.038425     -0.048193
# Loss of appetite             0.061349 -0.088203     0.246262      0.152160
# injury/cut                   0.012460  0.178340     0.077621     -0.097351
# Asthama                      0.127075 -0.110180     0.128347     -0.023672
# Ring worm                    0.199601  0.114735     0.257613     -0.069859
# foot pain                    0.292150 -0.005543     0.352837     -0.041487
# pain wrist                   0.245951 -0.018451     0.018875     -0.023672
# Swelling                     0.170712  0.069190     0.185790      0.156839
# watering of eye              0.008198 -0.018451     0.018875     -0.023672
# Indigestion                 -0.128876  0.222188    0.018875
# Hypertension                -0.033674 -0.031909   -0.023672
# Dehydration                 -0.016541 -0.015674   -0.011628
# Low BP                      -0.016541 -0.015674   -0.011628
# Oral ulcer                   0.071526 -0.069352    0.152014
# Anaemia                     -0.016541 -0.015674   -0.011628
# old abbrassion              -0.023529 -0.022296   -0.016541
# Fungal infection             0.261250  0.132134    0.132279
# Abdomen pain                -0.028989 -0.027469   -0.020378
# Itching                     -0.077847  0.231834   -0.054725
# Cough                       -0.061357  0.363376   -0.043133
# Cold                         0.051235  0.066834   -0.004678
# Ear Infection               -0.028989 -0.027469   -0.020378
# GAD                         -0.016541 -0.015674   -0.011628
# APD                         -0.031737  0.144351   -0.022311
# Throat pain                 -0.031737 -0.030073   -0.022311
# Back pain                   -0.039633 -0.037555   -0.027861
# General weakness            -0.041748 -0.039559   -0.029348
# Gastritis                   -0.016541 -0.015674   -0.011628
# Epigastric pain             -0.028989 -0.027469   -0.020378
# Fever                       -0.020607  0.103575   -0.069282
# Breathlessness              -0.016541 -0.015674   -0.011628
# Hairfall                    -0.016541 -0.015674   -0.011628
# Headache                     0.109224  0.050841   -0.040412
# Giddiness                   -0.041748 -0.039559   -0.029348
# Worm infection              -0.023529 -0.022296   -0.016541
# Rheumatic fever             -0.016541 -0.015674   -0.011628
# Vomitting                   -0.031737 -0.030073   -0.022311
# Myalgia                     -0.041748 -0.039559   -0.029348
# Running nose                -0.039460 -0.037391   -0.027740
# pharyngotis                 -0.022296 -0.021127   -0.015674
# vertigo                     -0.033674 -0.031909   -0.023672
# allergy                      0.332532 -0.031909   -0.023672
# Loss of appetite            -0.031737  0.318776   -0.022311
# injury/cut                  -0.068023 -0.064457   -0.047819
# Asthama                     -0.016541 -0.015674   -0.011628
# Ring worm                   -0.048813 -0.046254   -0.034315
# foot pain                   -0.028989 -0.027469   -0.020378
# pain wrist                  -0.016541 -0.015674   -0.011628
# Swelling                    -0.041748 -0.039559   -0.029348
# watering of eye             -0.016541 -0.015674   -0.011628
# Knee pain                   -0.023529 -0.022296   -0.016541
# LRTI                        -0.031737 -0.030073   -0.022311
# Diarhoea                    -0.041748 -0.039559   -0.029348
# Dysentry                    -0.023529 -0.022296   -0.016541
# Systeric HTN                -0.023529 -0.022296   -0.016541
# acute torillitis            -0.016541 -0.015674   -0.011628
# follicular torillitis       -0.016541 -0.015674   -0.011628
# Burn                         1.000000 -0.022296   -0.016541
# Lathergy                    -0.022296  1.000000   -0.015674
# Blood Clot                  -0.016541 -0.015674    1.000000
#
# [53 rows x 53 columns]

# %%
sns.set(style="white")

# %%
mask = np.triu(np.ones_like(corrltn, dtype=np.bool))

# %%
f, ax = plt.subplots(figsize=(20, 20))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corrltn, mask=mask, cmap=cmap, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
data.plot(y="Urti")

# %%
data_urti = pd.DataFrame(data=data, columns=["Urti"] )
data_urti.head()
# Out:
#             Urti
# Date
# 2018-06-20     1
# 2018-06-21     0
# 2018-06-22     1
# 2018-06-25     0
# 2018-06-27     1

# %%
data_urti.plot()

# %%
diff = data_urti.diff(periods=1)
diff=diff[1:]

# %%
diff.plot()

# %%
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(data_urti)

# %%
plot_acf(diff)
