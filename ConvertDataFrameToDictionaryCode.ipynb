# %%
import sys
import pandas as pd
from pandas import datetime
def parser(x):
    return datetime.strptime(x,'%d-%m-%Y')

# %%
df=pd.read_csv("Urti.csv",index_col=0,date_parser=parser,parse_dates=[0])
# Out:
# /home/manjit/.local/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime instead.
#   """

# %%
df.head()
# Out:
#             Urti
# Date
# 2018-06-01     0
# 2018-06-02     0
# 2018-06-03     0
# 2018-06-04     0
# 2018-06-05     0

# %%
df.index
# Out:
# DatetimeIndex(['2018-06-01', '2018-06-02', '2018-06-03', '2018-06-04',
#                '2018-06-05', '2018-06-06', '2018-06-07', '2018-06-08',
#                '2018-06-09', '2018-06-10',
#                ...
#                '2019-06-21', '2019-06-22', '2019-06-23', '2019-06-24',
#                '2019-06-25', '2019-06-26', '2019-06-27', '2019-06-28',
#                '2019-06-29', '2019-06-30'],
#               dtype='datetime64[ns]', name='Date', length=395, freq=None)

# %%
index_list=df.index
col=list(df.columns)[-1]
disease_vals=df[col].values
d={k:v for k,v in zip(index_list,disease_vals)}
d2={str(k.date()):float(v) for k,v in zip(index_list,disease_vals)}

# %%
type(list(d2.values())[0])
# Out:
# float

# %%
d2
# Out:
# {'2018-06-01': 0.0,
#  '2018-06-02': 0.0,
#  '2018-06-03': 0.0,
#  '2018-06-04': 0.0,
#  '2018-06-05': 0.0,
#  '2018-06-06': 0.0,
#  '2018-06-07': 0.0,
#  '2018-06-08': 0.0,
#  '2018-06-09': 0.0,
#  '2018-06-10': 0.0,
#  '2018-06-11': 0.0,
#  '2018-06-12': 0.0,
#  '2018-06-13': 0.0,
#  '2018-06-14': 0.0,
#  '2018-06-15': 0.0,
#  '2018-06-16': 0.0,
#  '2018-06-17': 0.0,
#  '2018-06-18': 0.0,
#  '2018-06-19': 0.0,
#  '2018-06-20': 1.0,
#  '2018-06-21': 0.0,
#  '2018-06-22': 1.0,
#  '2018-06-23': 0.0,
#  '2018-06-24': 0.0,
#  '2018-06-25': 0.0,
#  '2018-06-26': 0.0,
#  '2018-06-27': 1.0,
#  '2018-06-28': 0.0,
#  '2018-06-29': 0.0,
#  '2018-06-30': 0.0,
#  '2018-07-01': 0.0,
#  '2018-07-02': 1.0,
#  '2018-07-03': 0.0,
#  '2018-07-04': 0.0,
#  '2018-07-05': 0.0,
#  '2018-07-06': 0.0,
#  '2018-07-07': 0.0,
#  '2018-07-08': 0.0,
#  '2018-07-09': 2.0,
#  '2018-07-10': 3.0,
#  '2018-07-11': 0.0,
#  '2018-07-12': 1.0,
#  '2018-07-13': 1.0,
#  '2018-07-14': 0.0,
#  '2018-07-15': 0.0,
# ...

# %%
for i in df.index:
    print(str(i.date()))
# Out:
# 2018-06-01
# 2018-06-02
# 2018-06-03
# 2018-06-04
# 2018-06-05
# 2018-06-06
# 2018-06-07
# 2018-06-08
# 2018-06-09
# 2018-06-10
# 2018-06-11
# 2018-06-12
# 2018-06-13
# 2018-06-14
# 2018-06-15
# 2018-06-16
# 2018-06-17
# 2018-06-18
# 2018-06-19
# 2018-06-20
# 2018-06-21
# 2018-06-22
# 2018-06-23
# 2018-06-24
# 2018-06-25
# 2018-06-26
# 2018-06-27
# 2018-06-28
# 2018-06-29
# 2018-06-30
# 2018-07-01
# 2018-07-02
# 2018-07-03
# 2018-07-04
# 2018-07-05
# 2018-07-06
# 2018-07-07
# 2018-07-08
# 2018-07-09
# 2018-07-10
# 2018-07-11
# 2018-07-12
# 2018-07-13
# 2018-07-14
# 2018-07-15
# 2018-07-16
# 2018-07-17
# 2018-07-18
# 2018-07-19
# 2018-07-20
# 2018-07-21
# 2018-07-22
# 2018-07-23
# 2018-07-24
# 2018-07-25
# 2018-07-26
# 2018-07-27
# 2018-07-28
# 2018-07-29
# 2018-07-30
# 2018-07-31
# 2018-08-01
# 2018-08-02
# 2018-08-03
# 2018-08-04
# 2018-08-05
# 2018-08-06
# 2018-08-07
# 2018-08-08
# 2018-08-09
# 2018-08-10
# 2018-08-11
# 2018-08-12
# 2018-08-13
# 2018-08-14
# 2018-08-15
# ...
