# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas import datetime

# %%
def parser(x):
    return datetime.strptime(x,'%Y-%m-%d')

# %%
df_acidity = pd.read_csv('Acidity.csv', index_col=[0], date_parser=parser, parse_dates=[0])
df_acidity.head()
# Out:
#             Acidity
# Date
# 2018-06-20        2
# 2018-06-21        0
# 2018-06-22        1
# 2018-06-23        0
# 2018-06-24        0

# %%
df_acidity.plot()

# %%
df_coughcold = pd.read_csv('Cough_Cold.csv', index_col=[0], date_parser=parser, parse_dates=[0])
df_coughcold.head()
# Out:
#             Cough_Cold
# Date
# 2018-06-20           0
# 2018-06-21           0
# 2018-06-22           2
# 2018-06-23           0
# 2018-06-24           0

# %%
df_coughcold.plot()

# %%
df_funinf = pd.read_csv('Fungal infection.csv', index_col=[0], date_parser=parser, parse_dates=[0])
df_funinf.head()
# Out:
#             Fungal infection
# Date
# 2018-06-20                 0
# 2018-06-21                 0
# 2018-06-22                 1
# 2018-06-23                 0
# 2018-06-24                 0

# %%
df_funinf.plot()

# %%
df_indig = pd.read_csv('Indigestion.csv', index_col=[0], date_parser=parser, parse_dates=[0])
df_indig.head()
# Out:
#             Indigestion
# Date
# 2018-06-20            1
# 2018-06-21            0
# 2018-06-22            0
# 2018-06-23            0
# 2018-06-24            0

# %%
df_indig.plot()

# %%
df_urti = pd.read_csv('Urti.csv', index_col=[0], date_parser=parser, parse_dates=[0])
df_urti.head()
# Out:
#             Urti
# Date
# 2018-06-20     1
# 2018-06-21     0
# 2018-06-22     1
# 2018-06-23     0
# 2018-06-24     0

# %%
df_urti.plot()
