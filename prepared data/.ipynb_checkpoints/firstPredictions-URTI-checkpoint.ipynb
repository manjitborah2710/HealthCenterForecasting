# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas import datetime

# %%
def parser(x):
    return datetime.strptime(x,'%d-%m-%Y')

# %%
df=pd.read_csv('prepared_individual_data/Urti.csv',index_col=0,parse_dates=[0],date_parser=parser)

# %%
df.head()
# Out:
#             Urti
# Date
# 2018-06-01     0
# 2018-06-02     0
# 2018-06-03     0
# 2018-06-04     0
# 2018-06-05     0

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
df.plot()

# %%
df_urti_weeklyS = df.resample('W').sum()
df_urti_weeklyM = df.resample('W').mean()

# %%
df_urti_weeklyM.plot()

# %%
df_urti_weeklyS.plot()

# %%
df_diff=df.diff(1)

# %%
df_diff=df_diff[1:]

# %%
df_diff.plot()

# %%
plot_acf(df_urti_weeklyM);

# %%
plot_pacf(df_urti_weeklyM);

# %% [markdown]
# # AR on weekly data with 1 time differencing

# %%
df_weekly=df_urti_weeklyM
#.diff(1)[1:]

# %%
df_weekly.head()
# Out:
#                 Urti
# Date
# 2018-06-10  0.000000
# 2018-06-17  0.000000
# 2018-06-24  0.285714
# 2018-07-01 -0.142857
# 2018-07-08  0.000000

# %%
df_weekly.plot()

# %%
df_weekly.size
# Out:
# 56

# %%
plot_acf(df_weekly);

# %%
plot_pacf(df_weekly);

# %%
total=df_weekly
test_size=int(0.25*total.size)
train_size=total.size-test_size

# %%
test_size
# Out:
# 98

# %%
train_size
# Out:
# 294

# %%
total.size
# Out:
# 392

# %%
train=total[:train_size]

# %%
test=total[train_size:]

# %%
train.size+test.size
# Out:
# 392

# %%
from statsmodels.tsa.ar_model import AR

# %%
model=AR(total)
model_fit=model.fit()
# Out:
# c:\program files\python36\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)

# %%
from statsmodels.tsa.arima_model import ARMA

# %%
arma_model=ARMA(total,order=(0,9))
arma_model_fit=arma_model.fit()
# Out:
# c:\program files\python36\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# c:\program files\python36\lib\site-packages\statsmodels\base\model.py:548: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)

# %%
arma_preds=arma_model_fit.predict(start=(train_size),end=total.size)

# %%
preds=model_fit.predict(start=(train_size),end=total.size)

# %%
preds.size
# Out:
# 99

# %%
arma_preds.size
# Out:
# 99

# %%
plt.plot(test,label='Actual')
plt.plot(preds,color='red',label='Predicted')
plt.legend()

# %%
plt.plot(test,label='Actual')
plt.plot(arma_preds,color='red',label='Predicted')
plt.legend()

# %%
model_fit.aic
# Out:
# 1.8790039555926863

# %%
arma_model_fit.aic
# Out:
# 1813.8289319903424

# %%
model.exog_names
# Out:
# ['const',
#  'L1.Urti',
#  'L2.Urti',
#  'L3.Urti',
#  'L4.Urti',
#  'L5.Urti',
#  'L6.Urti',
#  'L7.Urti',
#  'L8.Urti',
#  'L9.Urti',
#  'L10.Urti',
#  'L11.Urti',
#  'L12.Urti',
#  'L13.Urti',
#  'L14.Urti',
#  'L15.Urti',
#  'L16.Urti',
#  'L17.Urti']

# %%
model_fit.aic
# Out:
# 1.8790039555926863

# %% [markdown]
# # ARIMA model

# %%
df_arima=df_urti_weeklyM

# %%
df_arima.plot()

# %%
total=df_arima
test_size=int(0.25*total.size)
train_size=total.size-test_size

# %%
test_size
# Out:
# 14

# %%
train_size
# Out:
# 43

# %%
total.size
# Out:
# 57

# %%
train=total[:train_size]

# %%
test=total[train_size:]

# %%
train.size+test.size
# Out:
# 57

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
model=ARIMA(train,order=(1,1,1))

# %%
fit_model=model.fit()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-c8974d174048> in <module>
# ----> 1 fit_model=model.fit()
#
# c:\program files\python36\lib\site-packages\statsmodels\tsa\arima_model.py in fit(self, start_params, trend, method, transparams, solver, maxiter, full_output, disp, callback, start_ar_lags, **kwargs)
#    1198                                         method, transparams, solver,
#    1199                                         maxiter, full_output, disp,
# -> 1200                                         callback, start_ar_lags, **kwargs)
#    1201         normalized_cov_params = None  # TODO: fix this?
#    1202         arima_fit = ARIMAResults(self, mlefit._results.params,
#
# c:\program files\python36\lib\site-packages\statsmodels\tsa\arima_model.py in fit(self, start_params, trend, method, transparams, solver, maxiter, full_output, disp, callback, start_ar_lags, **kwargs)
#     984         else:  # estimate starting parameters
#     985             start_params = self._fit_start_params((k_ar, k_ma, k), method,
# --> 986                                                   start_ar_lags)
#     987
#     988         if transparams:  # transform initial parameters to ensure invertibility
#
# c:\program files\python36\lib\site-packages\statsmodels\tsa\arima_model.py in _fit_start_params(self, order, method, start_ar_lags)
#     575                 return -self.loglike_css(params)
#     576
# --> 577             start_params = self._fit_start_params_hr(order, start_ar_lags)
#     578             if self.transparams:
#     579                 start_params = self._invtransparams(start_params)
#
# c:\program files\python36\lib\site-packages\statsmodels\tsa\arima_model.py in _fit_start_params_hr(self, order, start_ar_lags)
#     553         if p and not np.all(np.abs(np.roots(np.r_[1, -start_params[k:k + p]]
#     554                                             )) < 1):
# --> 555             raise ValueError("The computed initial AR coefficients are not "
#     556                              "stationary\nYou should induce stationarity, "
#     557                              "choose a different model order, or you can\n"
#
# ValueError: The computed initial AR coefficients are not stationary
# You should induce stationarity, choose a different model order, or you can
# pass your own start_params.

# %%
fit_model.aic
# Out:
# 127.2735997677336

# %%
preds=fit_model.forecast(steps=test_size)[0]

# %%
preds.size
# Out:
# 14

# %%
test.size
# Out:
# 14

# %%
plt.plot(test)

# %%
plt.plot(preds,color='red')

# %%
p=d=q=range(5)
import itertools

# %%
params=list(itertools.product(p,d,q))

# %%
len(params)
# Out:
# 125

# %%
min_param=()
min_aic=300
import warnings as wngs
wngs.filterwarnings('ignore')
for par in params:
    try:
        model=ARIMA(train,order=(par[0],par[1],par[2]))
        model_fit=model.fit()
        aic=model_fit.aic
        if aic!=None and aic<min_aic:
            min_aic=aic
            min_param=par
    except:
        continue

# %%
min_param
# Out:
# (1, 1, 1)

# %%
min_aic
# Out:
# 127.2735997677336
